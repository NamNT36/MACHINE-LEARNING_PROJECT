# %%
# import các thư viện xử lý dữ liệu
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## GET DATA ##

# %%
# Load tập dữ liệu "crabs.csv"
crabs_df = pd.read_csv("crabs.csv")

# %%
# Hiển thị 5 dòng đầu tiên dữ liệu của loài cua xanh (B)
crabs_df.head()
# Out:
#   sex  index  fontallip  rearwidth  length  width  depth speies
# 0   M      1        8.1        6.7    16.1   19.0    7.0      B
# 1   M      2        8.8        7.7    18.1   20.8    7.4      B
# 2   M      3        9.2        7.8    19.0   22.4    7.7      B
# 3   M      4        9.6        7.9    20.1   23.1    8.2      B
# 4   M      5        9.8        8.0    20.3   23.0    8.2      B

# %%
# Hiển thị 5 dòng đầu tiên dữ liệu của loài cua hồng (O)
crabs_df.iloc[101:106]
# Out:
#     sex  index  fontallip  rearwidth  length  width  depth speies
# 101   M      2       10.2        8.2    20.2   22.2    9.0      O
# 102   M      3       10.7        8.6    20.7   22.7    9.2      O
# 103   M      4       11.4        9.0    22.7   24.8   10.1      O
# 104   M      5       12.5        9.4    23.2   26.0   10.8      O
# 105   M      6       12.5        9.4    24.2   27.0   11.2      O

# %%
#Hiển thị tên các biến của các cột
# Load library
import collections

# Create dictionary
column_names = collections.defaultdict(str)

# Create keys
for name in crabs_df.columns:
     column_names[name]
# Show dictionary
column_names
# Out:
# defaultdict(str,
#             {'sex': '',
#              'index': '',
#              'fontallip': '',
#              'rearwidth': '',
#              'length': '',
#              'width': '',
#              'depth': '',
#              'speies': ''})

# %%
# hiện thị kích thước dữ liệu
print(crabs_df.shape)
# Out:
# (200, 8)

# %%
# mô tả về các đặc trưng của dữ liệu
print(crabs_df.describe())
# Out:
#             index   fontallip  rearwidth      length       width       depth
# count  200.000000  200.000000  200.00000  200.000000  200.000000  200.000000
# mean    25.500000   15.583000   12.73850   32.105500   36.414500   14.030500
# std     14.467083    3.495325    2.57334    7.118983    7.871955    3.424772
# min      1.000000    7.200000    6.50000   14.700000   17.100000    6.100000
# 25%     13.000000   12.900000   11.00000   27.275000   31.500000   11.400000
# 50%     25.500000   15.550000   12.80000   32.100000   36.800000   13.900000
# 75%     38.000000   18.050000   14.30000   37.225000   42.000000   16.600000
# max     50.000000   23.100000   20.20000   47.600000   54.600000   21.600000

# %%
# Hiển thị chiều rộng thân dài nhất
print('Maximum of rearwidth:', crabs_df['rearwidth'].max())
# Out:
# Maximum of rearwidth: 20.2

# %%
# Số lượng các loại cua có trong dataset
print(crabs_df.groupby('speies').size())
# Out:
# speies
# B    100
# O    100
# dtype: int64

# %%
# histograms
crabs_df.hist(edgecolor='black', linewidth=1.2)
# Out:
# array([[<AxesSubplot:title={'center':'index'}>,
#         <AxesSubplot:title={'center':'fontallip'}>],
#        [<AxesSubplot:title={'center':'rearwidth'}>,
#         <AxesSubplot:title={'center':'length'}>],
#        [<AxesSubplot:title={'center':'width'}>,
#         <AxesSubplot:title={'center':'depth'}>]], dtype=object)

# %%
from pandas.plotting import scatter_matrix
# scatter plot matrix
scatter_matrix(crabs_df,figsize=(10,10))
plt.show()
